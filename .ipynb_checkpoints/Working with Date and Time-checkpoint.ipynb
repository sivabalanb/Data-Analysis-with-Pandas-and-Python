# %%
import pandas as pd
import datetime as dt

# %%
someday = dt.date(2018,4,14)

# %%
someday.year
someday.month
someday.day
# Out:
# 14

# %%
str(dt.datetime(2018,4,14,8,50,44))
# Out:
# '2018-04-14 08:50:44'

# %%
sometime =dt.datetime(2018,4,14,8,50,44)

# %%
sometime.day
sometime.month
sometime.year
sometime.hour
sometime.minute
# Out:
# 50

# %%
pd.Timestamp('2015-1-6')
pd.Timestamp('2015/1/6')
pd.Timestamp('1/6/2015')
pd.Timestamp('12/19/2015')
pd.Timestamp('19/12/2015')
# Out:
# Timestamp('2015-12-19 00:00:00')

# %%
dates = ['2015-1-6','2015-5-6','2015-2-2']
dtIndex = pd.DatetimeIndex(dates)

# %%
values= [100,200,400]

# %%
pd.Series(data = values , index=dtIndex)
# Out:
# 2015-01-06    100
# 2015-05-06    200
# 2015-02-02    400
# dtype: int64

# %%
times = pd.date_range(start='2016', end='2018',freq='D')

# %%
type(times[0])
# Out:
# pandas._libs.tslib.Timestamp

# %%
times = pd.date_range(start='2016', end='2018',freq='w')

# %%
times
# Out:
# DatetimeIndex(['2016-01-03', '2016-01-10', '2016-01-17', '2016-01-24',
#                '2016-01-31', '2016-02-07', '2016-02-14', '2016-02-21',
#                '2016-02-28', '2016-03-06',
#                ...
#                '2017-10-29', '2017-11-05', '2017-11-12', '2017-11-19',
#                '2017-11-26', '2017-12-03', '2017-12-10', '2017-12-17',
#                '2017-12-24', '2017-12-31'],
#               dtype='datetime64[ns]', length=105, freq='W-SUN')

# %%
pd.date_range(start='2016', end='2018',freq='w-FRI')
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-08', '2016-01-15', '2016-01-22',
#                '2016-01-29', '2016-02-05', '2016-02-12', '2016-02-19',
#                '2016-02-26', '2016-03-04',
#                ...
#                '2017-10-27', '2017-11-03', '2017-11-10', '2017-11-17',
#                '2017-11-24', '2017-12-01', '2017-12-08', '2017-12-15',
#                '2017-12-22', '2017-12-29'],
#               dtype='datetime64[ns]', length=105, freq='W-FRI')

# %%
pd.date_range(start='2016', end='2018',freq='5H')
# Out:
# DatetimeIndex(['2016-01-01 00:00:00', '2016-01-01 05:00:00',
#                '2016-01-01 10:00:00', '2016-01-01 15:00:00',
#                '2016-01-01 20:00:00', '2016-01-02 01:00:00',
#                '2016-01-02 06:00:00', '2016-01-02 11:00:00',
#                '2016-01-02 16:00:00', '2016-01-02 21:00:00',
#                ...
#                '2017-12-29 23:00:00', '2017-12-30 04:00:00',
#                '2017-12-30 09:00:00', '2017-12-30 14:00:00',
#                '2017-12-30 19:00:00', '2017-12-31 00:00:00',
#                '2017-12-31 05:00:00', '2017-12-31 10:00:00',
#                '2017-12-31 15:00:00', '2017-12-31 20:00:00'],
#               dtype='datetime64[ns]', length=3509, freq='5H')

# %%
pd.date_range(start='2016', end='2018',freq='M')
# Out:
# DatetimeIndex(['2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30',
#                '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31',
#                '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31',
#                '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30',
#                '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
#                '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range(start='2016', end='2018',freq='A')
# Out:
# DatetimeIndex(['2016-12-31', '2017-12-31'], dtype='datetime64[ns]', freq='A-DEC')

# %%
pd.date_range(start='2014', periods=25)
# Out:
# DatetimeIndex(['2014-01-01', '2014-01-02', '2014-01-03', '2014-01-04',
#                '2014-01-05', '2014-01-06', '2014-01-07', '2014-01-08',
#                '2014-01-09', '2014-01-10', '2014-01-11', '2014-01-12',
#                '2014-01-13', '2014-01-14', '2014-01-15', '2014-01-16',
#                '2014-01-17', '2014-01-18', '2014-01-19', '2014-01-20',
#                '2014-01-21', '2014-01-22', '2014-01-23', '2014-01-24',
#                '2014-01-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
bunch_of_dates = pd.date_range(start='2000',end='2016', freq='2D')

# %%
a = pd.Series(bunch_of_dates)

# %%
a.head()
# Out:
# 0   2000-01-01
# 1   2000-01-03
# 2   2000-01-05
# 3   2000-01-07
# 4   2000-01-09
# dtype: datetime64[ns]

# %%
a.dt.day
# Out:
# 0        1
# 1        3
# 2        5
# 3        7
# 4        9
# 5       11
# 6       13
# 7       15
# 8       17
# 9       19
# 10      21
# 11      23
# 12      25
# 13      27
# 14      29
# 15      31
# 16       2
# 17       4
# 18       6
# 19       8
# 20      10
# 21      12
# 22      14
# 23      16
# 24      18
# 25      20
# 26      22
# 27      24
# 28      26
# 29      28
#         ..
# 2893     4
# 2894     6
# 2895     8
# 2896    10
# 2897    12
# 2898    14
# 2899    16
# 2900    18
# 2901    20
# 2902    22
# 2903    24
# 2904    26
# 2905    28
# 2906    30
# 2907     2
# 2908     4
# 2909     6
# 2910     8
# 2911    10
# 2912    12
# 2913    14
# 2914    16
# 2915    18
# 2916    20
# 2917    22
# 2918    24
# 2919    26
# 2920    28
# 2921    30
# 2922     1
# Length: 2923, dtype: int64

# %%
a.dt.weekday_name
# Out:
# 0        Saturday
# 1          Monday
# 2       Wednesday
# 3          Friday
# 4          Sunday
# 5         Tuesday
# 6        Thursday
# 7        Saturday
# 8          Monday
# 9       Wednesday
# 10         Friday
# 11         Sunday
# 12        Tuesday
# 13       Thursday
# 14       Saturday
# 15         Monday
# 16      Wednesday
# 17         Friday
# 18         Sunday
# 19        Tuesday
# 20       Thursday
# 21       Saturday
# 22         Monday
# 23      Wednesday
# 24         Friday
# 25         Sunday
# 26        Tuesday
# 27       Thursday
# 28       Saturday
# 29         Monday
#           ...
# 2893    Wednesday
# 2894       Friday
# 2895       Sunday
# 2896      Tuesday
# 2897     Thursday
# 2898     Saturday
# 2899       Monday
# 2900    Wednesday
# 2901       Friday
# 2902       Sunday
# 2903      Tuesday
# 2904     Thursday
# 2905     Saturday
# 2906       Monday
# 2907    Wednesday
# 2908       Friday
# 2909       Sunday
# 2910      Tuesday
# 2911     Thursday
# 2912     Saturday
# 2913       Monday
# 2914    Wednesday
# 2915       Friday
# 2916       Sunday
# 2917      Tuesday
# 2918     Thursday
# 2919     Saturday
# 2920       Monday
# 2921    Wednesday
# 2922       Friday
# Length: 2923, dtype: object

# %%
from pandas_datareader import data

# %%
company = "MSFT"
start =  "2010-01-01"
end = "2016-12-12"

# %%
stocks = data.DataReader(name = company,data_source="yahoo",start = start, end = end)

# %%
stocks.loc['2014-04-01']
stocks.iloc[299]
# Out:
# Open         2.562000e+01
# High         2.571000e+01
# Low          2.535000e+01
# Close        2.541000e+01
# Adj Close    2.120187e+01
# Volume       6.654950e+07
# Name: 2011-03-10 00:00:00, dtype: float64

# %%
birthday = pd.date_range(start='2000-04-01', end='2016-04-01', freq=pd.DateOffset(years=1))

# %%
mask = stocks.index.isin(birthday)

# %%
stocks.loc[mask]
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2010-04-01  29.350000  29.540001  28.620001  29.160000  23.805187  74768100
# 2011-04-01  25.530001  25.530001  25.309999  25.480000  21.260283  63114200
# 2013-04-01  28.639999  28.660000  28.360001  28.610001  25.258524  29201100
# 2014-04-01  41.150002  41.590000  41.070000  41.419998  37.645252  32605000
# 2015-04-01  40.599998  40.759998  40.310001  40.720001  38.008038  36752000
# 2016-04-01  55.049999  55.610001  54.570000  55.570000  53.284435  24399200

# %%
stocks.insert(0,"Day of the Week",stocks.index.weekday_name)

stocks.insert(1,"Week Day",stocks.index.weekday_namee)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-89ea74640c0c> in <module>()
# ----> 1 stocks.insert(0,"Day of the Week",stocks.index.weekday_name)
#       2
#       3 stocks.insert(1,"Week Day",stocks.index.weekday_namee)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    2421         value = self._sanitize_column(column, value, broadcast=False)
#    2422         self._data.insert(loc, column, value,
# -> 2423                           allow_duplicates=allow_duplicates)
#    2424
#    2425     def assign(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in insert(self, loc, item, value, allow_duplicates)
#    3808         if not allow_duplicates and item in self.items:
#    3809             # Should this be a different kind of error??
# -> 3810             raise ValueError('cannot insert {}, already exists'.format(item))
#    3811
#    3812         if not isinstance(loc, int):
#
# ValueError: cannot insert Day of the Week, already exists

# %%
someday = stocks.index[299]

# %%
someday.weekday_name
# Out:
# 'Thursday'

# %%
stocks.head()
# Out:
#             Day of the Week   Week Day       Open       High        Low  \
# Date
# 2009-12-31                3   Thursday  30.980000  30.990000  30.480000
# 2010-01-04                0     Monday  30.620001  31.100000  30.590000
# 2010-01-05                1    Tuesday  30.850000  31.100000  30.639999
# 2010-01-06                2  Wednesday  30.879999  31.080000  30.520000
# 2010-01-07                3   Thursday  30.629999  30.700001  30.190001
#
#                 Close  Adj Close    Volume
# Date
# 2009-12-31  30.480000  24.766968  31929700
# 2010-01-04  30.950001  25.148876  38409100
# 2010-01-05  30.959999  25.157001  49749600
# 2010-01-06  30.770000  25.002611  58182400
# 2010-01-07  30.450001  24.742592  50559700

# %%
stocks.insert(1,"Week Day",stocks.index.weekday_name)

# %%
stocks.truncate(before="2009-12-31", after="2011-12-31")
# 2011-12-02  25.219999  21.475464   52293800
# 2011-12-05  25.700001  21.884195   56818400
# 2011-12-06  25.660000  21.850142   46175300
# 2011-12-07  25.600000  21.799046   62667000
# 2011-12-08  25.400000  21.628735   60522200
# 2011-12-09  25.700001  21.884195   53788500
# 2011-12-12  25.510000  21.722408   38945900
# 2011-12-13  25.760000  21.935287   54581100
# 2011-12-14  25.590000  21.790531   47926400
# 2011-12-15  25.559999  21.764980   46213900
# 2011-12-16  26.000000  22.139652  101408100
# 2011-12-19  25.530001  21.739437   52258300
# 2011-12-20  26.030001  22.165199   60767600
# 2011-12-21  25.760000  21.935287   64132500
# 2011-12-22  25.809999  21.977861   35794100
# 2011-12-23  26.030001  22.165199   23205800
# 2011-12-27  26.040001  22.173714   21287200
# 2011-12-28  25.820000  21.986376   29822500
# 2011-12-29  26.020000  22.156683   22616900
# 2011-12-30  25.959999  22.105593   27395700
#
# [505 rows x 8 columns]

# %%
stocks.index + pd.DateOffset(months = 4)
# Out:
# DatetimeIndex(['2010-04-30', '2010-05-04', '2010-05-05', '2010-05-06',
#                '2010-05-07', '2010-05-08', '2010-05-11', '2010-05-12',
#                '2010-05-13', '2010-05-14',
#                ...
#                '2017-03-29', '2017-03-30', '2017-04-01', '2017-04-02',
#                '2017-04-05', '2017-04-06', '2017-04-07', '2017-04-08',
#                '2017-04-09', '2017-04-12'],
#               dtype='datetime64[ns]', name='Date', length=1750, freq=None)

# %%
stocks.index+ pd.tseries.offsets.MonthEnd()
# Out:
# DatetimeIndex(['2010-01-31', '2010-01-31', '2010-01-31', '2010-01-31',
#                '2010-01-31', '2010-01-31', '2010-01-31', '2010-01-31',
#                '2010-01-31', '2010-01-31',
#                ...
#                '2016-11-30', '2016-12-31', '2016-12-31', '2016-12-31',
#                '2016-12-31', '2016-12-31', '2016-12-31', '2016-12-31',
#                '2016-12-31', '2016-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1750, freq=None)

# %%
timeA = pd.Timestamp('2010-01-31')
timeB = pd.Timestamp('2016-01-31')

# %%
timeA - timeB
# Out:
# Timedelta('-2191 days +00:00:00')

# %%
type(timeA - timeB)
# Out:
# pandas._libs.tslib.Timedelta

# %%
pd.Timedelta(days = 4, weeks = 8, hours = 12)
# Out:
# Timedelta('60 days 12:00:00')

# %%
pd.Timedelta("6 hours 12 minutes")
# Out:
# Timedelta('0 days 06:12:00')

# %%
shipping = pd.read_csv('ecommerce.csv', index_col='ID', parse_dates=['order_date','delivery_date'])

# %%
shipping['delivery_time'] = shipping['delivery_date'] - shipping['order_date']

# %%
shipping.head()
# Out:
#    order_date delivery_date delivery_time
# ID
# 1  1998-05-24    1999-02-05      257 days
# 2  1992-04-22    1998-03-06     2144 days
# 4  1991-02-10    1992-08-26      563 days
# 5  1992-07-21    1997-11-20     1948 days
# 7  1993-09-02    1998-06-10     1742 days

