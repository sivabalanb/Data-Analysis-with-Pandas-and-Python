# %%
import pandas as pd
from pandas_datareader import data

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
production = pd.read_csv("mobile_2.csv")
production_idx = pd.read_csv("mobile_2.csv", index_col="Item", parse_dates=True)

production_idx
# Out:
#                                      2000-01  2001-02  2002-03  2003-04  \
# Item
# Consumer Electronics                 11950.0  12700.0  13800.0  15200.0
# Industrial Electronics                4000.0   4500.0   5550.0   6100.0
# Computer Hardware                     3400.0   3550.0   4250.0   6800.0
# Mobile Handsets                       4500.0   4500.0   4800.0   5350.0
# Strategic Electronics                 1750.0   1800.0   2500.0   2750.0
# Electronics Components                 500.0   5700.0   6600.0   7600.0
# LED (Part of Electronic Components)      NaN      NaN      NaN      NaN
# Sub-Total (Hardware)                 31100.0  32750.0  37500.0  43800.0
# Software for Exports                 28350.0  36500.0  46100.0  58240.0
# Domestic Software                     9400.0  10874.0  13400.0  16250.0
# Sub-Total (Software)                 37750.0  47374.0  59500.0  16250.0
#
#                                       2004-05   2005-06   2006-07   2007-08  \
# Item
# Consumer Electronics                  16800.0   18000.0   20000.0   22600.0
# Industrial Electronics                 8300.0    8800.0   10400.0   11910.0
# Computer Hardware                      8800.0   10800.0   12800.0   15870.0
# Mobile Handsets                        4800.0    7000.0    9500.0   18700.0
# Strategic Electronics                  3000.0    3200.0    4500.0    5700.0
# Electronics Components                 8800.0    8800.0    8800.0    9630.0
# LED (Part of Electronic Components)       NaN       NaN       NaN       NaN
# Sub-Total (Hardware)                  50500.0   56600.0   66000.0   84410.0
# Software for Exports                  80180.0  104100.0  141000.0  164400.0
# Domestic Software                     21740.0   29600.0   37000.0   47010.0
# Sub-Total (Software)                 101920.0  133700.0  178000.0  211410.0
#
#                                       2008-09   2009-10   2010-11   2011-12  \
# Item
# Consumer Electronics                  25550.0   29000.0   32000.0   34300.0
# Industrial Electronics                12740.0   15160.0   17000.0   18700.0
# Computer Hardware                     13490.0   14970.0   14970.0   16500.0
# Mobile Handsets                       26600.0   31000.0   35400.0   40500.0
# Strategic Electronics                  6840.0    6980.0    7700.0    8500.0
# Electronics Components                12040.0   13610.0   21800.0   24800.0
# LED (Part of Electronic Components)       NaN       NaN       NaN       NaN
# Sub-Total (Hardware)                  97260.0  110720.0  128870.0  143300.0
# Software for Exports                 216190.0  237000.0  268610.0  332769.0
# Domestic Software                     59000.0   67800.0   78700.0   91766.0
# Sub-Total (Software)                 275190.0  304800.0  347310.0  424535.0
#
#                                      2012-13  2013-14  2014-15 2015-16
# Item
# Consumer Electronics                   40447    47599    55806     NA
# Industrial Electronics                 25800    33600    39374   45083
# Computer Hardware                       9376    17484    18691     NA
# Mobile Handsets                        34600    26650    18900   54000
# Strategic Electronics                   9000    13800    15700     NA
# Electronics Components                 26645    32102    39723     NA
# LED (Part of Electronic Components)     1275     1941     2172    3590
# Sub-Total (Hardware)                  147143   173176   190366  102673
# Software for Exports                  412191   527292   600000  700000
# Domestic Software                     104700   114784   129432  140455
# Sub-Total (Software)                  516891   642076   729432  840455

# %%
production_t = production_idx.transpose()
production_t

path = r"mobile_t.xlsx"

writer = pd.ExcelWriter(path, engine = 'xlsxwriter')
production_t.to_excel(writer)
writer.save()
writer.close()

# %%
type(production_t)
# Out:
# method

# %%
import plotly
from plotly.graph_objs import Scatter, Layout
import plotly.graph_objs as go


literate = [go.Bar(x=production_t.index, y=production_t["Mobile Handsets"])]


plotly.offline.plot({ 'data': literate,
            'layout': {
               'title': 'POPULATION LITERACY RATE IN TN',
               'xaxis': {
                 'title': 'YEAR'},
               'yaxis': {
                'title': 'POPULATION (in lakhs) '}
        }})
# Out:
# 'file:///Users/siva/Documents/Code/Pandas/temp-plot.html'

# %%
plt.style.use("ggplot")

# %%
production.plot(x="Item")

# %%
production_idx.plot()
